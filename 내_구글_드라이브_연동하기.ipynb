# %% [markdown]
# <a href="https://colab.research.google.com/github/baek0618/colab_test/blob/master/%EB%82%B4_%EA%B5%AC%EA%B8%80_%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C_%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 구글 드라이브 colab 연동하기 <br>
#
# [colab에서 다음 명령을 수행 해보자]
# 1. from google.colab import drive <br>
#     drive.mount('/content/drive')  #마운트 하고 <br>
# 2. /content/My drive/ 경로를 확인하면 자신의 google drive 폴더 및 파일들을 확인 할 수 있다.
#
# ** ! 명령어 : 터미널에서 명령을 수행한다. ex. ! ls -al

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pwd  #/content 
# !ls -al /content/drive/'My Drive'/'Colab Notebooks'/drive

import PIL.Image as pilimg
import numpy as np
import matplotlib.pyplot as plt

im = pilimg.open('/content/drive/My Drive/Colab Notebooks/drive/images.jpg')
pix = np.array(im)

plt.imshow(pix)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# total 7
# -rw------- 1 root root 6972 Nov  3 06:27 images.jpg

# %% [markdown]
# # 공유 문서함 가져오기<br>
#
# 1. 공유 문서함 우클릭
# 2. 내 드라이브에 추가하기
#
# - 내 드라이브에 공유 문서함이 생겼다!

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pwd  #/content 
# !ls -al /content/drive/'My Drive'/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# total 10136
# drwx------ 2 root root     4096 Sep  4 08:25 '억대연봉의 4인 딥러닝팟'
# drwx------ 3 root root     4096 Nov  3 05:03 'Colab Notebooks'
# -rw------- 1 root root 10240760 Sep  5 08:06  face2_9.5_500장.zip
# -rw------- 1 root root      287 Nov  3 06:09  Untitled
# -rw------- 1 root root   124241 Nov  3 06:49  Untitled0.ipynb
# -rw------- 1 root root     4247 Nov  3 06:08  Untitled1.ipynb

# %% [markdown]
# # 구글드라이브 공유 id를 이용해서 1개의 파일만 불러오기<br>
#
# 1. 구글 드라이브에서 불러올 파일 우클릭
# 2. 공유가능한 링크가져오기 <br>
#     ex. https://drive.google.com/open?id=1tJMcQ8EFppMZWVo0shCIssF4RS6rBstX 가 복사됨 <br>
# 3. id= 이후만 복사해서 downloaded = drive.CreateFile({'id': **file_id**})  # file_id 에 저장 <br>
# 4. downloaded.GetContentFile('yado.jpg')  # 'yado.jpg' 란 이름으로 현재 경로에 저장 (아무 이름 가능)

# %%
# !pip install -U -q PyDrive

import PIL.Image as pilimg
import numpy as np
import matplotlib.pyplot as plt
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials 
 
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
file_id = '1S07MNhyEzJSqOodfTQLOdVNbP_7Iq1OX'   
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('yado.jpg')  # 'yado.jpg' 란 이름으로 현재 경로에 저장

# !ls -al

im = pilimg.open('./yado.jpg')
pix = np.array(im)

plt.imshow(pix)
# Out:
# ls: cannot access 'drive2': Transport endpoint is not connected
# ls: cannot access 'drive3': Transport endpoint is not connected
# total 56
# drwxr-xr-x 1 root root 4096 Nov  3 07:20 .
# drwxr-xr-x 1 root root 4096 Nov  3 05:02 ..
# -rw-r--r-- 1 root root 2548 Nov  3 05:51 adc.json
# -rw-r--r-- 1 root root 6547 Nov  3 07:20 a.jpg
# drwxr-xr-x 1 root root 4096 Nov  3 05:51 .config
# drwx------ 3 root root 4096 Nov  3 06:42 drive
# d????????? ? ?    ?       ?            ? drive2
# d????????? ? ?    ?       ?            ? drive3
# drwxr-xr-x 2 root root 4096 Nov  1 16:42 sample_data
# -rw-r--r-- 1 root root 6972 Nov  3 06:22 schema.csv
# -rw-r--r-- 1 root root 6547 Nov  3 07:25 yado.jpg
